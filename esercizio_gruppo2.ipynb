# %%
# !apt-get install lammps

# %% [markdown]
# Eseguiamo la simulazione a densità 4 kg/m^3

# %%
# !mpirun --allow-run-as-root -np 1 lammps -in BENZENE_in.LJ_3D_NVT
# Out:
# Output streaming troncato alle ultime 5000 righe.
# 195481 299521.728294632
# 195482 299524.018142512
# 195483 299526.285963472
# 195484 299528.552087846
# 195485 299530.85616976
# 195486 299533.188680414
# 195487 299535.458305402
# 195488 299537.708503437
# 195489 299539.98844376
# 195490 299542.289304581
# 195490 -40.6719931208289 1584.53673450067 1625.2087276215 532.111349181083 2.27168664732966 32461759
# 195491 299544.550185056
# 195492 299546.762156992
# 195493 299549.016559391
# 195494 299551.301232792
# 195495 299553.584114659
# 195496 299555.842849762
# 195497 299558.07557584
# 195498 299560.3446746
# 195499 299562.65806171
# 195500 299564.941172537
# 195500 -39.8512467773635 1535.12542003733 1574.9766668147 515.518284071624 2.21045703324792 32461759
# 195501 299567.190423516
# 195502 299569.451340008
# 195503 299571.727956417
# 195504 299574.005466913
# 195505 299576.276887387
# 195506 299578.53931287
# 195507 299580.801015454
# 195508 299583.086607015
# ...

# %% [markdown]
# **Variabili termodinamiche nella fase di equilibrazione**

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit


THERMO_file = np.genfromtxt('thermodynamics_equilibration_319.dat',  delimiter=" ")
time = THERMO_file[:, 0]
U = THERMO_file[:, 1] 
K = THERMO_file[:, 2] 
E = THERMO_file[:, 3]
T = THERMO_file[:, 4]
P = THERMO_file[:, 5]
V = THERMO_file[:, 6]

plt.title("Variabili termodinamiche - equilibrazione")
plt.xlabel("t [fs]")
plt.plot(time, T)

# %%
THERMO_file = np.genfromtxt('thermodynamics_equilibration_319.dat',  delimiter=" ")
time = THERMO_file[:, 0]
U = THERMO_file[:, 1] 
K = THERMO_file[:, 2] 
E = THERMO_file[:, 3]
T = THERMO_file[:, 4]
P = THERMO_file[:, 5]
V = THERMO_file[:, 6]

plt.title("Variabili termodinamiche - equilibrazione")
plt.xlabel("t [fs]")
plt.plot(time, P)

# %% [markdown]
# **Dinamica nella fase di produzione**

# %%
MSD_file = np.genfromtxt('msd_319.dat', delimiter=' ')
time = MSD_file[:, 0]
msd = MSD_file[:, 1]
plt.figure(1)
plt.xlabel("t [fs]")
plt.ylabel("MSD [Angstrom^2]")
plt.title("MSD vs Tempo (Scala lineare)")
plt.plot(time,msd)

plt.figure(2)
plt.loglog(time,msd)
plt.xlabel("t [fs]")
plt.ylabel("MSD [Angstrom^2]")
plt.title("MSD vs Tempo (Scala logaritmica)")

def linea_retta(t,D):
  return 6*D*t

D, err = curve_fit(linea_retta,time,msd)

plt.figure(3)
plt.loglog(time,msd)
plt.plot(time,linea_retta(time,D), '--')
plt.xlabel("t [fs]")
plt.ylabel("MSD [Angstrom^2]")
plt.title("MSD vs Tempo (Scala logaritmica)")
print(D)
# Out:
# [0.21982757]

# %% [markdown]
# Eseguiamo ora la simulazione a densità 5.9 kg/m^3

# %%
# !mpirun --allow-run-as-root -np 1 lammps -in BENZENE2_in.LJ_3D_NVT
# Out:
# Output streaming troncato alle ultime 5000 righe.
# 195481 241293.485506239
# 195482 241295.103760977
# 195483 241296.742502517
# 195484 241298.389804726
# 195485 241300.011957013
# 195486 241301.598573851
# 195487 241303.219452
# 195488 241304.863631649
# 195489 241306.501442904
# 195490 241308.123202989
# 195490 -48.6922997871975 1521.31174321787 1570.00404300507 510.879442920446 3.0867450859658 21952000
# 195491 241309.744031388
# 195492 241311.400870605
# 195493 241313.063149056
# 195494 241314.685425508
# 195495 241316.302910162
# 195496 241317.938177372
# 195497 241319.582474988
# 195498 241321.210899169
# 195499 241322.794814674
# 195500 241324.400510323
# 195500 -49.0977501779662 1550.43467824736 1599.53242842533 520.659364024981 3.14067304816827 21952000
# 195501 241326.040972593
# 195502 241327.683170972
# 195503 241329.308922741
# 195504 241330.920345856
# 195505 241332.558211806
# 195506 241334.225136082
# 195507 241335.863591274
# 195508 241337.480722529
# ...

# %% [markdown]
# **Variabili termodinamiche nella fase di equilibrazione**

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit


THERMO_file = np.genfromtxt('thermodynamics_equilibration_280.dat',  delimiter=" ")
time = THERMO_file[:, 0]
U = THERMO_file[:, 1] 
K = THERMO_file[:, 2] 
E = THERMO_file[:, 3]
T = THERMO_file[:, 4]
P = THERMO_file[:, 5]
V = THERMO_file[:, 6]

plt.title("Variabili termodinamiche - equilibrazione")
plt.xlabel("t [fs]")
plt.plot(time, T)

# %%
THERMO_file = np.genfromtxt('thermodynamics_equilibration_280.dat',  delimiter=" ")
time = THERMO_file[:, 0]
U = THERMO_file[:, 1] 
K = THERMO_file[:, 2] 
E = THERMO_file[:, 3]
T = THERMO_file[:, 4]
P = THERMO_file[:, 5]
V = THERMO_file[:, 6]

plt.title("Variabili termodinamiche - equilibrazione")
plt.xlabel("t [fs]")
plt.ylim(2.5,5)
plt.plot(time, P)

# %% [markdown]
# **Dinamica nella fase di produzione**

# %%
MSD_file = np.genfromtxt('msd_280.dat', delimiter=' ')
time = MSD_file[:, 0]
msd = MSD_file[:, 1]
plt.figure(1)
plt.xlabel("t [fs]")
plt.ylabel("MSD [Angstrom^2]")
plt.title("MSD vs Tempo (Scala lineare)")
plt.plot(time,msd)

plt.figure(2)
plt.loglog(time,msd)
plt.xlabel("t [fs]")
plt.ylabel("MSD [Angstrom^2]")
plt.title("MSD vs Tempo (Scala logaritmica)")

def linea_retta(t,D):
  return 6*D*t

D, err = curve_fit(linea_retta,time,msd)

plt.figure(3)
plt.loglog(time,msd)
plt.plot(time,linea_retta(time,D), '--')
plt.xlabel("t [fs]")
plt.ylabel("MSD [Angstrom^2]")
plt.title("MSD vs Tempo (Scala logaritmica)")
# Out:
# Text(0.5, 1.0, 'MSD vs Tempo (Scala logaritmica)')

# %% [markdown]
# Eseguiamo ora la simulazione a densità 7.4 kg/m^3

# %%
# !mpirun --allow-run-as-root -np 1 lammps -in BENZENE3_in.LJ_3D_NVT
# Out:
# Output streaming troncato alle ultime 5000 righe.
# 195481 214586.014563467
# 195482 214587.314672328
# 195483 214588.649908243
# 195484 214589.963629249
# 195485 214591.256700388
# 195486 214592.548349405
# 195487 214593.856093604
# 195488 214595.183915787
# 195489 214596.48670563
# 195490 214597.764255053
# 195490 -48.2663299065201 1517.44599182495 1565.71232173147 509.581265261011 3.84201770118086 17576000
# 195491 214599.058683598
# 195492 214600.371545903
# 195493 214601.673689941
# 195494 214602.940027842
# 195495 214604.195412968
# 195496 214605.500560178
# 195497 214606.812656078
# 195498 214608.104078568
# 195499 214609.385278121
# 195500 214610.689508231
# 195500 -48.09126166794 1609.69287501129 1657.78413667923 540.559160819551 4.08407661774425 17576000
# 195501 214612.011317153
# 195502 214613.306488767
# 195503 214614.584010379
# 195504 214615.875391373
# 195505 214617.183968709
# 195506 214618.49048394
# 195507 214619.768075802
# 195508 214621.041237049
# ...

# %% [markdown]
# **Variabili termodinamiche nella fase di equilibrazione**

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit


THERMO_file = np.genfromtxt('thermodynamics_equilibration_260.dat',  delimiter=" ")
time = THERMO_file[:, 0]
U = THERMO_file[:, 1] 
K = THERMO_file[:, 2] 
E = THERMO_file[:, 3]
T = THERMO_file[:, 4]
P = THERMO_file[:, 5]
V = THERMO_file[:, 6]

plt.title("Variabili termodinamiche - equilibrazione")
plt.xlabel("t [fs]")
plt.plot(time, T)

# %%
THERMO_file = np.genfromtxt('thermodynamics_equilibration_260.dat',  delimiter=" ")
time = THERMO_file[:, 0]
U = THERMO_file[:, 1] 
K = THERMO_file[:, 2] 
E = THERMO_file[:, 3]
T = THERMO_file[:, 4]
P = THERMO_file[:, 5]
V = THERMO_file[:, 6]

plt.title("Variabili termodinamiche - equilibrazione")
plt.xlabel("t [fs]")
plt.ylim(3,5)
plt.plot(time, P)

# %% [markdown]
# **Dinamica nella fase di produzione**

# %%
MSD_file = np.genfromtxt('msd_260.dat', delimiter=' ')
time = MSD_file[:, 0]
msd = MSD_file[:, 1]
plt.figure(1)
plt.xlabel("t [fs]")
plt.ylabel("MSD [Angstrom^2]")
plt.title("MSD vs Tempo (Scala lineare)")
plt.plot(time,msd)

plt.figure(2)
plt.loglog(time,msd)
plt.xlabel("t [fs]")
plt.ylabel("MSD [Angstrom^2]")
plt.title("MSD vs Tempo (Scala logaritmica)")

def linea_retta(t,D):
  return 6*D*t

D, err = curve_fit(linea_retta,time,msd)

plt.figure(3)
plt.loglog(time,msd)
plt.plot(time,linea_retta(time,D), '--')
plt.xlabel("t [fs]")
plt.ylabel("MSD [Angstrom^2]")
plt.title("MSD vs Tempo (Scala logaritmica)")
# Out:
# Text(0.5, 1.0, 'MSD vs Tempo (Scala logaritmica)')

# %% [markdown]
# Eseguiamo la simulazione a densità 9.4 kg/m^3

# %%
# !mpirun --allow-run-as-root -np 1 lammps -in BENZENE4_in.LJ_3D_NVT
# Out:
# Output streaming troncato alle ultime 5000 righe.
# 198527 187022.587239544
# 198528 187023.831225958
# 198529 187025.091480044
# 198530 187026.320178199
# 198530 -72.1107130616562 1512.79616513838 1584.90687820004 508.019783284748 4.81662669338744 13824000
# 198531 187027.537254589
# 198532 187028.769737724
# 198533 187030.01363989
# 198534 187031.242810258
# 198535 187032.439777262
# 198536 187033.654997481
# 198537 187034.890461687
# 198538 187036.127089045
# 198539 187037.354529627
# 198540 187038.57158326
# 198540 -72.5748803466524 1519.89786223125 1592.4727425779 510.404640346929 4.82319626129372 13824000
# 198541 187039.801581758
# 198542 187041.05614633
# 198543 187042.295211258
# 198544 187043.510631981
# 198545 187044.733183321
# 198546 187045.967734361
# 198547 187047.204563486
# 198548 187048.42810197
# 198549 187049.62365594
# 198550 187050.838850723
# 198550 -72.9872624615793 1566.87426592543 1639.861528387 526.180025672572 4.9626688547679 13824000
# ...

# %% [markdown]
# **Variabili termodinamiche nella fase di equilibrazione**

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit

THERMO_file = np.genfromtxt('thermodynamics_equilibration_240.dat',  delimiter=" ")
time = THERMO_file[:, 0]
U = THERMO_file[:, 1] 
K = THERMO_file[:, 2] 
E = THERMO_file[:, 3]
T = THERMO_file[:, 4]
P = THERMO_file[:, 5]
V = THERMO_file[:, 6]

plt.title("Variabili termodinamiche - equilibrazione")
plt.xlabel("t [fs]")
plt.plot(time, T)

# %%
THERMO_file = np.genfromtxt('thermodynamics_equilibration_240.dat',  delimiter=" ")
time = THERMO_file[:, 0]
U = THERMO_file[:, 1] 
K = THERMO_file[:, 2] 
E = THERMO_file[:, 3]
T = THERMO_file[:, 4]
P = THERMO_file[:, 5]
V = THERMO_file[:, 6]

plt.title("Variabili termodinamiche - equilibrazione")
plt.xlabel("t [fs]")
plt.ylim(4,7)
plt.plot(time, P)

# %% [markdown]
# **Dinamica nella fase di produzione**

# %%
MSD_file = np.genfromtxt('msd_240.dat', delimiter=' ')
time = MSD_file[:, 0]
msd = MSD_file[:, 1]
plt.figure(1)
plt.xlabel("t [fs]")
plt.ylabel("MSD [Angstrom^2]")
plt.title("MSD vs Tempo (Scala lineare)")
plt.plot(time,msd)

plt.figure(2)
plt.loglog(time,msd)
plt.xlabel("t [fs]")
plt.ylabel("MSD [Angstrom^2]")
plt.title("MSD vs Tempo (Scala logaritmica)")

def linea_retta(t,D):
  return 6*D*t

D, err = curve_fit(linea_retta,time,msd)

plt.figure(3)
plt.loglog(time,msd)
plt.plot(time,linea_retta(time,D), '--')
plt.xlabel("t [fs]")
plt.ylabel("MSD [Angstrom^2]")
plt.title("MSD vs Tempo (Scala logaritmica)")
# Out:
# Text(0.5, 1.0, 'MSD vs Tempo (Scala logaritmica)')

# %% [markdown]
# Eseguiamo la simulazione a densità 12.2 kg/m^3

# %%
# !mpirun --allow-run-as-root -np 1 lammps -in BENZENE5_in.LJ_3D_NVT
# Out:
# Output streaming troncato alle ultime 5000 righe.
# 195481 147386.72865073
# 195482 147387.599499073
# 195483 147388.474380054
# 195484 147389.372052419
# 195485 147390.259692653
# 195486 147391.127370589
# 195487 147391.997818428
# 195488 147392.883570663
# 195489 147393.770459085
# 195490 147394.629190715
# 195490 -86.3647467845239 1477.51523895062 1563.87998573514 496.171915813221 6.14818904474609 10648000
# 195491 147395.491546059
# 195492 147396.372799976
# 195493 147397.256240984
# 195494 147398.128299628
# 195495 147398.987203678
# 195496 147399.852862578
# 195497 147400.742114806
# 195498 147401.627285236
# 195499 147402.495017865
# 195500 147403.363963442
# 195500 -86.0615265262987 1557.86215660516 1643.92368313146 523.1536233526 6.49947370926207 10648000
# 195501 147404.252803769
# 195502 147405.146227534
# 195503 147406.006882777
# 195504 147406.872721145
# 195505 147407.759286639
# 195506 147408.64552541
# 195507 147409.514180678
# 195508 147410.380507072
# ...

# %% [markdown]
# **Variabili termodinamiche nella fase di equilibrazione**

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit


THERMO_file = np.genfromtxt('thermodynamics_equilibration_220.dat',  delimiter=" ")
time = THERMO_file[:, 0]
U = THERMO_file[:, 1] 
K = THERMO_file[:, 2] 
E = THERMO_file[:, 3]
T = THERMO_file[:, 4]
P = THERMO_file[:, 5]
V = THERMO_file[:, 6]

plt.title("Variabili termodinamiche - equilibrazione")
plt.xlabel("t [fs]")
plt.ylim(5,10)
plt.plot(time, P)

# %%
THERMO_file = np.genfromtxt('thermodynamics_equilibration_220.dat',  delimiter=" ")
time = THERMO_file[:, 0]
U = THERMO_file[:, 1] 
K = THERMO_file[:, 2] 
E = THERMO_file[:, 3]
T = THERMO_file[:, 4]
P = THERMO_file[:, 5]
V = THERMO_file[:, 6]

plt.title("Variabili termodinamiche - equilibrazione")
plt.xlabel("t [fs]")
plt.plot(time, T)

# %% [markdown]
# **Dinamica nella fase di produzione**

# %%
MSD_file = np.genfromtxt('msd_220.dat', delimiter=' ')
time = MSD_file[:, 0]
msd = MSD_file[:, 1]
plt.figure(1)
plt.xlabel("t [fs]")
plt.ylabel("MSD [Angstrom^2]")
plt.title("MSD vs Tempo (Scala lineare)")
plt.plot(time,msd)

plt.figure(2)
plt.loglog(time,msd)
plt.xlabel("t [fs]")
plt.ylabel("MSD [Angstrom^2]")
plt.title("MSD vs Tempo (Scala logaritmica)")

def linea_retta(t,D):
  return 6*D*t

D, err = curve_fit(linea_retta,time,msd)

plt.figure(3)
plt.loglog(time,msd)
plt.plot(time,linea_retta(time,D), '--')
plt.xlabel("t [fs]")
plt.ylabel("MSD [Angstrom^2]")
plt.title("MSD vs Tempo (Scala logaritmica)")
# Out:
# Text(0.5, 1.0, 'MSD vs Tempo (Scala logaritmica)')

# %% [markdown]
# ### **Calcolo della pressione media in output $\langle P \rangle$**

# %% [markdown]
# ### **Confronto tra l'equazione di stato dei gas ideali e quella di van der Waals**

# %% [markdown]
# $P_{ideale} = \frac{nRT}{V}$

# %% [markdown]
# $P_{vdW} = \frac{nRT - \frac{an^2}{V} + \frac{abn^3}{V^2}}{V-nb}$

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit

# Dati della simulazione in input (variabili termodinamiche)
N = 1000  # numero di particelle
T = 523   # temperatura
R = 8.31  # costante dei gas
N_A = 6.022*10**23 # Numero di Avogadro
n = N/N_A # Calcolo numero di moli

# Dati della simulazione in output
p_simulazione = np.array([6.42,4.98,3.94,3.17,2.16])
# output delle simulazioni a diverse densità (restringendo il volume della
# scatola mantenendo cost il numero di particelle) (in atm)
p_simulazione = p_simulazione*10**5  # in Pa
L_simulazione = np.array([220,240,260,280,319])*10**(-10) # in m
V_simulazione = L_simulazione**3 #definisco i volumi come i cubi dei lati della scatola

# Vettori per plot
L = np.linspace(200*10**(-10),330*10**(-10),10000) # in m
V = L**3 # in m^3

# Parametri dell'equazione di van der Waals per la CO2
a = 1.824 #(J*m^3)/(mol^2)
b = 0.0001154 #m^3/mol

# Equazioni di stato ideale e van der waals esplicitate nella pressione
p_vdW = (n*R*T - (a*n**2)/V + (a*b*n**3)/V**2)/(V-n*b)
p_ideale = (n*R*T)/V

# Isoterma in scala lineare
plt.figure(1)
plt.plot(L_simulazione,p_simulazione, 'o')  # i pallini sono i dati delle simulazioni
plt.plot(L,p_vdW, 'black')  # la linea nera è la previsione per van der waals
plt.plot(L,p_ideale, 'orange')  # la linea arancione è la previsione per l'eq. dei gas ideali
plt.xlim(200*10**(-10),330*10**(-10))
plt.ylim(0,0.1*10**(7))
plt.xlabel('L [m]')
plt.ylabel('P [Pa]')
plt.title('P vs L - scala lineare')

# Isoterma in scala logaritmica
plt.figure(2)
plt.loglog(L_simulazione,p_simulazione, 'o')
plt.loglog(L,p_vdW, 'black')
plt.loglog(L,p_ideale, 'orange')
plt.xlim(200*10**(-10),330*10**(-10))
plt.ylim(10**5,0.1*10**(7))
plt.xlabel('L [m]')
plt.ylabel('P [Pa]')
plt.title('P vs L - scala logaritmica')

# Scostamento percentuale dall'idealità
plt.figure(3)
plt.plot(L,abs((p_ideale-p_vdW)/(p_vdW))*100)
plt.xlim(200*10**(-10),330*10**(-10))
plt.ylim(0,10)
plt.xlabel('L [m]')
plt.ylabel('Scostamento %')
plt.title('Scostamento pressione VdW e ideale')
# Out:
# Text(0.5, 1.0, 'Scostamento pressione VdW e ideale')

# %% [markdown]
# ### **Dinamica nella fase di produzione**
# $ D = \lim_{t->+\infty} \frac{1}{6t}MSD$

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit

# Caricamento dei file
MSD_file = np.genfromtxt('msd_319.dat', delimiter=' ')
time = MSD_file[:, 0]
msd = MSD_file[:, 1]

# Plot MSD contro il tempo in scala lineare
plt.figure(1)
plt.xlabel("t [fs]")
plt.ylabel("MSD [Angstrom^2]")
plt.title("MSD vs Tempo (Scala lineare)")
plt.plot(time,msd)

# Plot MSD contro il tempo in scala logaritmica
plt.figure(2) 
plt.loglog(time,msd, '-')
plt.xlabel("t [fs]")
plt.ylabel("MSD [Angstrom^2]")
plt.title("MSD vs Tempo (Scala logaritmica)")

# Definizione della funzione che useremo per fittare i dati
def linea_retta(t,D):
  return 6*D*t

# Fit dei dati
D, err = curve_fit(linea_retta,time[10001:],msd[10001:])

# Plot MSD contro il tempo in scala logaritmica con fit
plt.figure(3)
plt.loglog(time,msd)
plt.plot(time,linea_retta(time,D), '--')
plt.xlabel("t [fs]")
plt.ylabel("MSD [Angstrom^2]")
plt.title("MSD vs Tempo (Scala logaritmica)")

print(D)
# Out:
# [0.21985256]

# %%
# Caricamento dei file
MSD_file = np.genfromtxt('msd_280.dat', delimiter=' ')
time = MSD_file[:, 0]
msd = MSD_file[:, 1]

# Plot MSD contro il tempo in scala lineare
plt.figure(1)
plt.xlabel("t [fs]")
plt.ylabel("MSD [Angstrom^2]")
plt.title("MSD vs Tempo (Scala lineare)")
plt.plot(time,msd)

# Plot MSD contro il tempo in scala logaritmica
plt.figure(2) 
plt.loglog(time,msd, '-')
plt.xlabel("t [fs]")
plt.ylabel("MSD [Angstrom^2]")
plt.title("MSD vs Tempo (Scala logaritmica)")

# Definizione della funzione che useremo per fittare i dati
def linea_retta(t,D):
  return 6*D*t

# Fit dei dati
D, err = curve_fit(linea_retta,time[10001:],msd[10001:])

# Plot MSD contro il tempo in scala logaritmica con fit
plt.figure(3)
plt.loglog(time,msd)
plt.plot(time,linea_retta(time,D), '--')
plt.xlabel("t [fs]")
plt.ylabel("MSD [Angstrom^2]")
plt.title("MSD vs Tempo (Scala logaritmica)")

print(D)
# Out:
# [0.18260934]

# %%
# Caricamento dei file
MSD_file = np.genfromtxt('msd_260.dat', delimiter=' ')
time = MSD_file[:, 0]
msd = MSD_file[:, 1]

# Plot MSD contro il tempo in scala lineare
plt.figure(1)
plt.xlabel("t [fs]")
plt.ylabel("MSD [Angstrom^2]")
plt.title("MSD vs Tempo (Scala lineare)")
plt.plot(time,msd)

# Plot MSD contro il tempo in scala logaritmica
plt.figure(2) 
plt.loglog(time,msd, '-')
plt.xlabel("t [fs]")
plt.ylabel("MSD [Angstrom^2]")
plt.title("MSD vs Tempo (Scala logaritmica)")

# Definizione della funzione che useremo per fittare i dati
def linea_retta(t,D):
  return 6*D*t

# Fit dei dati
D, err = curve_fit(linea_retta,time[10001:],msd[10001:])

# Plot MSD contro il tempo in scala logaritmica con fit
plt.figure(3)
plt.loglog(time,msd)
plt.plot(time,linea_retta(time,D), '--')
plt.xlabel("t [fs]")
plt.ylabel("MSD [Angstrom^2]")
plt.title("MSD vs Tempo (Scala logaritmica)")

print(D)
# Out:
# [0.16491835]

# %%
# Caricamento dei file
MSD_file = np.genfromtxt('msd_240.dat', delimiter=' ')
time = MSD_file[:, 0]
msd = MSD_file[:, 1]

# Plot MSD contro il tempo in scala lineare
plt.figure(1)
plt.xlabel("t [fs]")
plt.ylabel("MSD [Angstrom^2]")
plt.title("MSD vs Tempo (Scala lineare)")
plt.plot(time,msd)

# Plot MSD contro il tempo in scala logaritmica
plt.figure(2) 
plt.loglog(time,msd, '-')
plt.xlabel("t [fs]")
plt.ylabel("MSD [Angstrom^2]")
plt.title("MSD vs Tempo (Scala logaritmica)")

# Definizione della funzione che useremo per fittare i dati
def linea_retta(t,D):
  return 6*D*t

# Fit dei dati
D, err = curve_fit(linea_retta,time[10001:],msd[10001:])

# Plot MSD contro il tempo in scala logaritmica con fit
plt.figure(3)
plt.loglog(time,msd)
plt.plot(time,linea_retta(time,D), '--')
plt.xlabel("t [fs]")
plt.ylabel("MSD [Angstrom^2]")
plt.title("MSD vs Tempo (Scala logaritmica)")

print(D)
# Out:
# [0.14113557]

# %%
# Caricamento dei file
MSD_file = np.genfromtxt('msd_220.dat', delimiter=' ')
time = MSD_file[:, 0]
msd = MSD_file[:, 1]

# Plot MSD contro il tempo in scala lineare
plt.figure(1)
plt.xlabel("t [fs]")
plt.ylabel("MSD [Angstrom^2]")
plt.title("MSD vs Tempo (Scala lineare)")
plt.plot(time,msd)

# Plot MSD contro il tempo in scala logaritmica
plt.figure(2) 
plt.loglog(time,msd, '-')
plt.xlabel("t [fs]")
plt.ylabel("MSD [Angstrom^2]")
plt.title("MSD vs Tempo (Scala logaritmica)")

# Definizione della funzione che useremo per fittare i dati
def linea_retta(t,D):
  return 6*D*t

# Fit dei dati
D, err = curve_fit(linea_retta,time[10001:],msd[10001:])

# Plot MSD contro il tempo in scala logaritmica con fit
plt.figure(3)
plt.loglog(time,msd)
plt.plot(time,linea_retta(time,D), '--')
plt.xlabel("t [fs]")
plt.ylabel("MSD [Angstrom^2]")
plt.title("MSD vs Tempo (Scala logaritmica)")

print(D)
# Out:
# [0.11705505]

# %%
# Fit della diffusività contro L
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit

L = np.array([220,240,260,280,319])
D = np.array([0.12,0.14,0.16,0.18,0.22])

def func(x,a,b):
  return a*x+b

parametri,err = curve_fit(func,L,D)
print(parametri)

plt.plot(L,D,'o')
L = np.linspace(220,330,10000)
plt.plot(L,func(L,parametri[0],parametri[1]))
# Out:
# [ 0.0010095  -0.10230684]

# %% [markdown]
# Diffusività sulle y contro la lunghezza della scatola L sulle x
